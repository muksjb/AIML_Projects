# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd

Iris = pd.read_csv("Iris.csv")

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
 [print(x ,":", type(Iris[x])) for x in Iris.columns]
# Out:
# Sepal Length (in cm) : <class 'pandas.core.series.Series'>
# Sepal Width in (cm) : <class 'pandas.core.series.Series'>
# Petal length (in cm) : <class 'pandas.core.series.Series'>
# Petal width (in cm) : <class 'pandas.core.series.Series'>
# Class : <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris.head(10)
Iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
first_col = Iris.iloc[:,0]
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
Iris.rename(index=first_col)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 5.1                   5.1                  3.5                   1.4
# 4.9                   4.9                  3.0                   1.4
# 4.7                   4.7                  3.2                   1.3
# 4.6                   4.6                  3.1                   1.5
# 5.0                   5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 6.7                   6.7                  3.0                   5.2
# 6.3                   6.3                  2.5                   5.0
# 6.5                   6.5                  3.0                   5.2
# 6.2                   6.2                  3.4                   5.4
# 5.9                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 5.1                  0.2     Iris-setosa
# 4.9                  0.2     Iris-setosa
# 4.7                  0.2     Iris-setosa
# 4.6                  0.2     Iris-setosa
# 5.0                  0.2     Iris-setosa
# ..                   ...             ...
# 6.7                  2.3  Iris-virginica
# 6.3                  1.9  Iris-virginica
# 6.5                  2.0  Iris-virginica
# 6.2                  2.3  Iris-virginica
# 5.9                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.loc[:9,['Sepal Width in (cm)','Sepal Length (in cm)']]
# Out:
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris.loc[Iris['Class']=="Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
newColumn=Iris['Sepal Length (in cm)']*Iris['Sepal Width in (cm)']

# %%
Iris['SepalExtra']= newColumn
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class  SepalExtra
# 0                    0.2     Iris-setosa       17.85
# 1                    0.2     Iris-setosa       14.70
# 2                    0.2     Iris-setosa       15.04
# 3                    0.2     Iris-setosa       14.26
# 4                    0.2     Iris-setosa       18.00
# ..                   ...             ...         ...
# 145                  2.3  Iris-virginica       20.10
# 146                  1.9  Iris-virginica       15.75
# 147                  2.0  Iris-virginica       19.50
# 148                  2.3  Iris-virginica       21.08
# 149                  1.8  Iris-virginica       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
 [print(x ,":", Iris[x].mean()) for x in Iris.columns  if x!='Class']
# Out:
# Sepal Length (in cm) : 5.843333333333335
# Sepal Width in (cm) : 3.0540000000000007
# Petal length (in cm) : 3.7586666666666693
# Petal width (in cm) : 1.1986666666666672
# SpalExtra : 17.806533333333338
# [None, None, None, None, None]

# %%
    Iris.mean(numeric_only=float)
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SpalExtra               17.806533
# dtype: float64

# %%
 [print(x ,":", Iris[x].var()) for x in Iris.columns  if x!='Class']
# Out:
# Sepal Length (in cm) : 0.6856935123042505
# Sepal Width in (cm) : 0.18800402684563763
# Petal length (in cm) : 3.1131794183445156
# Petal width (in cm) : 0.5824143176733784
# [None, None, None, None]

# %%
    Iris.var(numeric_only=float)
# Out:
# Sepal Length (in cm)    0.685694
# Sepal Width in (cm)     0.188004
# Petal length (in cm)    3.113179
# Petal width (in cm)     0.582414
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def sum(a,b):
    print (a+b)
sum(Iris.get_value(0,"Sepal Length (in cm)"),Iris.get_value(0,"Sepal Width in (cm)"))
# Out:
# 8.6
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
Iris[:].max(numeric_only=float).subtract(Iris[:].min(numeric_only=float))
# Out:
# Sepal Length (in cm)     3.60
# Sepal Width in (cm)      2.40
# Petal length (in cm)     5.90
# Petal width (in cm)      2.40
# SpalExtra               20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values(by='Petal width (in cm)')
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# ..                    ...                  ...                   ...
# 140                   6.7                  3.1                   5.6
# 114                   5.8                  2.8                   5.1
# 100                   6.3                  3.3                   6.0
# 144                   6.7                  3.3                   5.7
# 109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class  SpalExtra
# 32                   0.1     Iris-setosa      21.32
# 13                   0.1     Iris-setosa      12.90
# 37                   0.1     Iris-setosa      15.19
# 9                    0.1     Iris-setosa      15.19
# 12                   0.1     Iris-setosa      14.40
# ..                   ...             ...        ...
# 140                  2.4  Iris-virginica      20.77
# 114                  2.4  Iris-virginica      16.24
# 100                  2.5  Iris-virginica      20.79
# 144                  2.5  Iris-virginica      22.11
# 109                  2.5  Iris-virginica      25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris= Iris.drop('SepalExtra', axis=1)
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[:10,:3]

# %%
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
DF = pd.read_csv('HR.txt',delimiter='\t')

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
row,col = DF.shape

# %%
row
# Out:
# 1470

# %%
col
# Out:
# 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
 [print("Type of ", x ,"Col is :", type(DF[x])) for x in DF.columns]
# Out:
# Type of  Individual  Col is : <class 'pandas.core.series.Series'>
# Type of  Attrition Col is : <class 'pandas.core.series.Series'>
# Type of  Age Col is : <class 'pandas.core.series.Series'>
# Type of  BusinessTravel Col is : <class 'pandas.core.series.Series'>
# Type of  DailyRate Col is : <class 'pandas.core.series.Series'>
# Type of  Department Col is : <class 'pandas.core.series.Series'>
# Type of  DistanceFromHome Col is : <class 'pandas.core.series.Series'>
# Type of  Education Col is : <class 'pandas.core.series.Series'>
# Type of  EducationField Col is : <class 'pandas.core.series.Series'>
# Type of  EmployeeCount Col is : <class 'pandas.core.series.Series'>
# Type of  EmployeeNumber Col is : <class 'pandas.core.series.Series'>
# Type of  EnvironmentSatisfaction Col is : <class 'pandas.core.series.Series'>
# Type of  Gender Col is : <class 'pandas.core.series.Series'>
# Type of  HourlyRate Col is : <class 'pandas.core.series.Series'>
# Type of  JobInvolvement Col is : <class 'pandas.core.series.Series'>
# Type of  JobLevel Col is : <class 'pandas.core.series.Series'>
# Type of  JobRole Col is : <class 'pandas.core.series.Series'>
# Type of  JobSatisfaction Col is : <class 'pandas.core.series.Series'>
# Type of  MaritalStatus Col is : <class 'pandas.core.series.Series'>
# Type of  MonthlyIncome Col is : <class 'pandas.core.series.Series'>
# Type of  MonthlyRate Col is : <class 'pandas.core.series.Series'>
# Type of  NumCompaniesWorked Col is : <class 'pandas.core.series.Series'>
# Type of  OverTime Col is : <class 'pandas.core.series.Series'>
# Type of  PercentSalaryHike Col is : <class 'pandas.core.series.Series'>
# Type of  PerformanceRating Col is : <class 'pandas.core.series.Series'>
# Type of  RelationshipSatisfaction Col is : <class 'pandas.core.series.Series'>
# Type of  StandardHours Col is : <class 'pandas.core.series.Series'>
# Type of  StockOptionLevel Col is : <class 'pandas.core.series.Series'>
# Type of  TotalWorkingYears Col is : <class 'pandas.core.series.Series'>
# Type of  TrainingTimesLastYear Col is : <class 'pandas.core.series.Series'>
# Type of  WorkLifeBalance Col is : <class 'pandas.core.series.Series'>
# Type of  YearsAtCompany Col is : <class 'pandas.core.series.Series'>
# Type of  YearsInCurrentRole Col is : <class 'pandas.core.series.Series'>
# Type of  YearsSinceLastPromotion Col is : <class 'pandas.core.series.Series'>
# Type of  YearsWithCurrManager Col is : <class 'pandas.core.series.Series'>
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
DF[3:11]
# Out:
#    Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 3         Ind4        No   33               2       1392           2
# 4         Ind5        No   27               1        591           2
# 5         Ind6        No   32               2       1005           2
# 6         Ind7        No   59               1       1324           2
# 7         Ind8        No   30               1       1358           2
# 8         Ind9        No   38               2        216           2
# 9        Ind10        No   36               1       1299           2
# 10       Ind11        No   35               1        809           2
#
#     DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 3                  3          4               1              1  ...
# 4                  2          1               2              1  ...
# 5                  2          2               1              1  ...
# 6                  3          3               2              1  ...
# 7                 24          1               1              1  ...
# 8                 23          3               1              1  ...
# 9                 27          3               2              1  ...
# 10                16          3               2              1  ...
#
#     RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 3                          3             80                 0
# 4                          4             80                 1
# 5                          3             80                 0
# 6                          1             80                 3
# 7                          2             80                 1
# 8                          2             80                 0
# 9                          2             80                 2
# 10                         3             80                 1
#
#     TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 3                   8                      3                3               8
# 4                   6                      3                3               2
# 5                   8                      2                2               7
# 6                  12                      3                2               1
# 7                   1                      2                3               1
# 8                  10                      2                3               9
# 9                  17                      3                2               7
# 10                  6                      5                3               5
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 3                    7                        3                     0
# 4                    2                        2                     2
# 5                    7                        3                     6
# 6                    0                        0                     0
# 7                    0                        0                     0
# 8                    7                        1                     8
# 9                    7                        7                     7
# 10                   4                        0                     3
#
# [8 rows x 35 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
DF['Gender'].isin(['1']).sum()
# Out:
# 882

# %%
DF['Gender'].isin(['2']).sum()
# Out:
# 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
DF['Age'].quantile(.75)-DF['Age'].quantile(.25)
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
DF['DailyRate'].mean()
DF['DailyRate'].median()
DF['DailyRate'].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f1=DF['Attrition'].value_counts()
f1.plot(kind='bar')

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
f1=DF['TotalWorkingYears'].value_counts()
f1.plot(kind='bar',figsize=(15,5))
